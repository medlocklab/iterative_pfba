# %%
import pandas as pd
import numpy as np
import matplotlib
import sklearn
import seaborn
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler

# %%
#import consumption production frame from pFBA analysis
fortyCP = pd.read_pickle("pFBA_df.pkl")
fortyCP_nutrients = fortyCP.columns

# %%
biolog = pd.read_csv('plata_biolog_raw.csv', index_col = 0)
biolog_nutrients = biolog.columns

# %%
intersection = biolog_nutrients.intersection(fortyCP_nutrients)
intersection
# Out:
# Index(['Dextrin', 'Maltose', 'Stachyose', 'D-Mannose', 'D-Fructose', 'Inosine',
#        'D-Mannitol', 'Glycerol', 'L-Alanine', 'L-Arginine', 'L-Histidine',
#        'L-Serine'],
#       dtype='object')

# %%
biolog_i = biolog[intersection]
fortyCP_i = fortyCP[intersection]

rank_b = biolog_i.rank(axis = 1)
rank_f = fortyCP_i.rank(axis = 1)
rank_b.sort_index(inplace = True)
rank_f.sort_index(inplace = True)

# %%
#creating scatterplot of rankings
i = 0
while i < rank_b.shape[0]:
    plt.scatter(rank_b.iloc[i], rank_f.iloc[i], alpha=0.2, c = 'b')
    i+=1
plt.xlabel('Experimental ranking')
plt.ylabel('Simulated ranking');

# %%
hexplot = seaborn.jointplot(rank_b, rank_f, kind = 'hex')
hexplot.set_axis_labels('Experimental ranking', 'Simulated ranking');

# %%
#ploting spearman correlation
from scipy.stats import spearmanr
i = 0
arr = [];
placeholder = pd.DataFrame(np.zeros((2,55)))
while i < fortyCP.shape[0]:
    if not np.isnan(spearmanr(rank_b.iloc[i],rank_f.iloc[i])[0]):
        arr.append(spearmanr(rank_b.iloc[i],rank_f.iloc[i])[0])
    i += 1
p = seaborn.stripplot(data=arr)
# Out:
# C:\Users\Caroline\Anaconda3\envs\capstone\lib\site-packages\numpy\lib\function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Caroline\Anaconda3\envs\capstone\lib\site-packages\numpy\lib\function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\Caroline\Anaconda3\envs\capstone\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\Caroline\Anaconda3\envs\capstone\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\Caroline\Anaconda3\envs\capstone\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
# plot of zscore(rank_biolog - rank_fba)
output = np.subtract(rank_b, rank_f)
output_z = output.apply(zscore)
p = seaborn.stripplot(data=output_z)

# %%
p = seaborn.stripplot(data=output_z.transpose())
p.set_xticklabels(output_z.index, rotation = 70, ha = 'right', size=8);

# %%
output = np.subtract(rank_b, rank_f)
fig, ax = plt.subplots()
im = ax.imshow(output,cmap='PiYG_r')
ax.set_xticks(np.arange(len(intersection)))
ax.set_xticklabels(intersection, rotation=90);
ax.set_yticks(np.arange(len(biolog_i.index)))
ax.set_yticklabels(biolog_i.index);
cb = plt.colorbar(im)

fig.set_size_inches(15, 15)
fig.tight_layout()

# %%
print(output_z)
#np.histogram(output)
plt.hist(output_z, bins = [-3 ,  -2,  -1,0,1, 2,3]); 
plt.xlabel('Biolog - pFBA')
plt.ylabel('Frequency')
plt.title('Histogram of Biolog/pFBA comparison')
# Out:
#                                                     Dextrin   Maltose  \
# Achromobacter piechaudii                          -0.178949 -1.414700
# Achromobacter xylosoxidans                         0.401425 -1.057302
# Aeromonas salmonicida                              0.594884  1.444483
# Bacillus megaterium                                0.014509  0.372289
# Bacillus pumilus                                  -1.339697 -1.533832
# Ralstonia solanacearum                             -0.427573  -0.361586
# Salmonella enterica subsp. enterica serovar Typhi  -1.538153  -0.027814
# Sphingobacterium spiritivorum                       0.683007   0.862243
# Staphylococcus aureus                              -1.760269  -0.361586
# Staphylococcus epidermidis                         -0.649689  -0.361586
# Staphylococcus haemolyticus                        -1.093921  -1.696671
# Stenotrophomonas maltophilia                       -1.538153   0.862243
# Streptococcus equinus                               2.015703  -0.027814
# Streptococcus gallolyticus                          1.793587   0.528471
# Streptococcus mitis                                 2.015703   0.305957
# Streptococcus oralis                                0.016659   0.305957
# Streptococcus pneumoniae                            1.127239   1.307271
# Streptococcus vestibularis                          0.016659   0.305957
#
#                                                    D-Fructose   Inosine  \
# Achromobacter piechaudii                            -0.026760 -1.095088
# Achromobacter xylosoxidans                           0.508432 -0.511041
# Aeromonas salmonicida                               -0.026760 -0.705724
# Bacillus megaterium                                 -2.167527  0.657053
# Bacillus pumilus                                     1.311220  0.462371
# Bacillus subtilis subsp. Spizizenii                 -0.829547 -0.900406
# Brachybacterium faecium                              1.846412  0.267688
# Brevundimonas diminuta                              -1.230941 -0.705724
# Chryseobacterium gleum                               0.776028 -0.705724
# Corynebacterium efficiens                           -0.561951 -0.316359
# Corynebacterium glutamicum                           0.240836  0.267688
# Enterococcus faecalis                                0.508432  0.657053
# Flavobacterium johnsoniae                            0.107038 -1.095088
# Gordonia bronchialis                                 0.240836 -0.900406
# Haemophilus influenzae                               1.578816  2.019829
# Haemophilus parasuis                                 1.311220  1.435782
# Kytococcus sedentarius                              -0.829547 -0.121676
# Listeria monocytogenes                              -0.428154  0.851735
# Listeria seeligeri                                  -0.428154  0.851735
# Neisseria flavescens                                -1.899931  0.073006
# Neisseria gonorrhoeae                                0.642230 -0.121676
# Neisseria meningitidis                               0.508432 -0.316359
# Neisseria mucosa                                    -0.294356  0.073006
# Pseudomonas mendocina                                1.043624 -0.900406
# Pseudomonas putida                                   1.311220 -0.511041
# Pseudomonas stutzeri                                 1.846412 -1.095088
# Ralstonia pickettii                                  0.374634 -0.705724
# Ralstonia solanacearum                              -1.632335 -0.900406
# Salmonella enterica subsp. enterica serovar Typhi   -0.695749  1.630465
# Sphingobacterium spiritivorum                        0.107038 -2.068500
# Staphylococcus aureus                               -0.294356  2.603877
# Staphylococcus epidermidis                           0.776028  0.657053
# Staphylococcus haemolyticus                         -1.498537  2.214512
# Stenotrophomonas maltophilia                         0.776028 -0.900406
# Streptococcus equinus                               -0.294356 -0.511041
# Streptococcus gallolyticus                          -1.632335 -0.511041
# Streptococcus mitis                                 -0.695749  0.462371
# Streptococcus oralis                                -0.561951 -0.511041
# Streptococcus pneumoniae                             0.374634  0.073006
# Streptococcus vestibularis                          -0.160558  0.851735
#
#                                                    D-Mannitol  Glycerol  \
# Achromobacter piechaudii                            -0.399190 -0.581541
# Achromobacter xylosoxidans                           0.248145 -0.166155
# Aeromonas salmonicida                               -1.046526  0.387694
# Bacillus megaterium                                 -1.478083  0.664619
# Bacillus pumilus                                     0.463924 -0.581541
# Bacillus subtilis subsp. Spizizenii                 -0.183412 -1.135390
# Brachybacterium faecium                              0.679702 -0.996928
# Brevundimonas diminuta                               0.032367 -0.304617
# Chryseobacterium gleum                              -0.830747  1.772316
# Corynebacterium efficiens                            0.463924 -0.027692
# Corynebacterium glutamicum                          -0.614969 -0.720003
# Enterococcus faecalis                               -0.399190 -0.027692
# Flavobacterium johnsoniae                           -0.399190 -0.581541
# Gordonia bronchialis                                -0.183412  1.218467
# Haemophilus influenzae                              -0.183412 -1.689239
# Haemophilus parasuis                                -1.262304 -2.104625
# Kytococcus sedentarius                               0.679702  0.110770
# Listeria monocytogenes                               0.248145 -0.443079
# Listeria seeligeri                                   0.032367  0.526156
# Neisseria flavescens                                 0.895481  0.249232
# Neisseria gonorrhoeae                                0.679702  1.910778
# Neisseria meningitidis                               0.463924  1.356930
# Neisseria mucosa                                     0.895481  0.249232
# Pseudomonas mendocina                               -0.183412  0.941543
# Pseudomonas putida                                  -1.046526 -0.166155
# Pseudomonas stutzeri                                 1.542816  0.387694
# Ralstonia pickettii                                  1.542816  1.356930
# Ralstonia solanacearum                               2.405930  1.633854
# Salmonella enterica subsp. enterica serovar Typhi    1.758595  0.387694
# Sphingobacterium spiritivorum                        1.111259  2.187703
# Staphylococcus aureus                               -0.614969  0.110770
# Staphylococcus epidermidis                          -0.399190 -0.166155
# Staphylococcus haemolyticus                         -1.909640  0.249232
# Stenotrophomonas maltophilia                        -1.262304 -1.135390
# Streptococcus equinus                                0.248145 -0.858466
# Streptococcus gallolyticus                           0.248145 -0.166155
# Streptococcus mitis                                  0.032367 -0.858466
# Streptococcus oralis                                 0.248145 -0.720003
# Streptococcus pneumoniae                            -2.772754 -0.443079
# Streptococcus vestibularis                           0.248145 -1.827701
#
#                                                    L-Alanine  L-Arginine  \
# Achromobacter piechaudii                            0.993021   -1.459980
# Achromobacter xylosoxidans                          1.373731   -0.960842
# Aeromonas salmonicida                              -0.402919    0.203815
# Bacillus megaterium                                 1.627538    1.368471
# Bacillus pumilus                                    1.627538    0.203815
# Bacillus subtilis subsp. Spizizenii                 1.754442    1.368471
# Brachybacterium faecium                            -1.671955   -1.959119
# Brevundimonas diminuta                              0.866117   -1.127221
# Chryseobacterium gleum                             -0.022208   -0.794462
# Corynebacterium efficiens                          -0.276015    0.702953
# Corynebacterium glutamicum                          0.358503    0.037435
# Enterococcus faecalis                              -1.037437    0.702953
# Flavobacterium johnsoniae                          -0.022208    0.203815
# Gordonia bronchialis                               -0.656726    0.869333
# Haemophilus influenzae                             -0.656726    0.203815
# Haemophilus parasuis                               -0.276015   -0.295324
# Kytococcus sedentarius                             -0.149112    1.368471
# Listeria monocytogenes                             -0.402919   -0.960842
# Listeria seeligeri                                 -0.529822   -1.127221
# Neisseria flavescens                               -0.149112    1.035712
# Neisseria gonorrhoeae                              -1.545051   -0.628083
# Neisseria meningitidis                             -1.671955   -0.794462
# Neisseria mucosa                                   -0.402919   -0.461703
# Pseudomonas mendocina                               0.104695    1.701230
# Pseudomonas putida                                  0.358503    2.366748
# Pseudomonas stutzeri                                2.642767   -1.459980
# Ralstonia pickettii                                 1.373731   -1.127221
# Ralstonia solanacearum                              1.246828   -1.293601
# Salmonella enterica subsp. enterica serovar Typhi  -0.529822   -0.295324
# Sphingobacterium spiritivorum                      -0.783630   -1.792739
# Staphylococcus aureus                              -1.164340    0.370194
# Staphylococcus epidermidis                         -0.910533    0.370194
# Staphylococcus haemolyticus                         0.739213    0.536574
# Stenotrophomonas maltophilia                        1.119924   -0.128944
# Streptococcus equinus                              -0.402919    0.536574
# Streptococcus gallolyticus                         -0.402919    0.536574
# Streptococcus mitis                                -0.529822    0.370194
# Streptococcus oralis                               -0.402919    0.702953
# Streptococcus pneumoniae                           -0.783630    0.370194
# Streptococcus vestibularis                         -0.402919    0.536574
#
#                                                    L-Histidine  L-Serine
# Achromobacter piechaudii                              1.330542  0.319096
# Achromobacter xylosoxidans                           -0.549572  0.687285
# Aeromonas salmonicida                                -0.260323  1.178202
# Bacillus megaterium                                   1.185918 -1.399115
# Bacillus pumilus                                     -1.128068 -0.417280
# Bacillus subtilis subsp. Spizizenii                   1.909038 -0.540009
# Brachybacterium faecium                              -1.128068 -1.030927
# Brevundimonas diminuta                                3.210655  0.687285
# Chryseobacterium gleum                               -1.561940 -0.171821
# Corynebacterium efficiens                            -0.404947  0.687285
# Corynebacterium glutamicum                           -1.128068  0.932744
# Enterococcus faecalis                                 0.028925 -0.662739
# Flavobacterium johnsoniae                            -0.983444 -0.171821
# Gordonia bronchialis                                  0.752045  0.810014
# Haemophilus influenzae                               -0.838820  1.914579
# Haemophilus parasuis                                 -0.549572 -1.644574
# Kytococcus sedentarius                               -0.260323 -1.767304
# Listeria monocytogenes                               -0.549572 -0.785468
# Listeria seeligeri                                    0.173549 -0.908198
# Neisseria flavescens                                 -0.115699  1.300932
# Neisseria gonorrhoeae                                -0.260323 -0.540009
# Neisseria meningitidis                               -0.404947 -0.662739
# Neisseria mucosa                                     -0.115699 -0.417280
# Pseudomonas mendocina                                 1.185918  0.441826
# Pseudomonas putida                                    1.185918  0.932744
# Pseudomonas stutzeri                                  0.173549 -1.153657
# Ralstonia pickettii                                   1.764414  0.196367
# Ralstonia solanacearum                                1.764414 -0.049092
# Salmonella enterica subsp. enterica serovar Typhi    -0.260323  1.914579
# Sphingobacterium spiritivorum                        -0.694196 -0.662739
# Staphylococcus aureus                                -0.260323  0.687285
# Staphylococcus epidermidis                           -0.983444  1.178202
# Staphylococcus haemolyticus                          -0.549572  2.037308
# Stenotrophomonas maltophilia                         -0.260323  1.178202
# Streptococcus equinus                                -0.549572 -0.785468
# Streptococcus gallolyticus                           -0.549572 -0.785468
# Streptococcus mitis                                  -0.694196 -0.908198
# Streptococcus oralis                                  0.607421 -0.785468
# Streptococcus pneumoniae                              0.318173 -1.153657
# Streptococcus vestibularis                           -0.549572  0.319096
# Text(0.5, 1.0, 'Histogram of Biolog/pFBA comparison')

# %%
#np.histogram(output)
plt.hist(output, bins = [-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]); 
plt.xlabel('Biolog - pFBA')
plt.ylabel('Frequency')
plt.title('Histogram of Biolog/pFBA comparison')
# Out:
# Text(0.5, 1.0, 'Histogram of Biolog/pFBA comparison')
